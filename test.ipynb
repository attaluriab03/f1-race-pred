# %%
import fastf1
import pandas as pd
import numpy as np
import time
from collections import defaultdict

# %% [markdown]
# no need to worry about caching - it is enabled by default

# %% [markdown]
# ## Features to Use
#
# #### Only trying to predict race order as of now
#
# 1. Qualifying Position - Qualifying to Race Position Delta
#     - change weight based on historical quali vs race order for different tracks
#     - this is a direct indicator of car and driver performance
# 2. Track Performance
#     - look at position changes in a race to get an idea of how order changes within the race
# 3.
#
# ### Training and Performance
#
# - make sure to train on data from way before, but weight recent performances higher (car and driver)
# - look at historical car performance on the track (only for last 3 years) (2022-2025)
# - look at historical driver performance on the track (only for last 3 years) (2022-2025)
#     - weight last 6 months of finishes higher
#
# - Train up until (and including) Bahrain GP in 2025
# - Test on all 2025 races to date

# %%
fastf1.Cache.get_cache_info()
# Out:
# (None, None)

# %%
fastf1.set_log_level('DEBUG')

# %% [markdown]
# No need to pull laps data for now either, only do load for results

# %%
years = list(range(2014, 2025))
raceData = defaultdict(list)
for year in years:
    # time.sleep(5)
    currYearSchedule = None
    if year < 2018:
        currYearSchedule = fastf1.get_event_schedule(year, include_testing=False, backend='ergast')
    else:
        currYearSchedule = fastf1.get_event_schedule(year, include_testing=False, backend='fastf1')
    for event in currYearSchedule['EventName']:
        raceResults = None
        if year < 2018:
            raceResults = fastf1.get_session(year, event, 'R', backend='ergast')
        else:
            raceResults = fastf1.get_session(year, event, 'R', backend='fastf1')
        raceResults.load(laps=False, telemetry=False, weather=False, messages=False)
        # time.sleep(1)
        df_race = raceResults.results
        df_race = df_race.drop(columns=['BroadcastName', 'TeamColor', 'HeadshotUrl', 'CountryCode'])
        df_race['PositionChange'] = df_race['GridPosition'] - df_race['Position']
        df_race['Year'] = year
        df_race['Event'] = event
        raceData[event].append(df_race)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (1.14 GB) /Users/abhiattaluri/Library/Caches/fastf1
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['6', '20', '22', '14', '77', '27', '7', '25', '26', '11', '99', '21', '4', '17', '8', '13', '9', '1', '44', '19', '10', '3']
# core           INFO 	Loading data for Malaysian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '1', '14', '27', '22', '19', '77', '20', '26', '8', '7', '10', '9', '4', '3', '21', '99', '25', '17', '13', '11']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '11', '3', '27', '1', '19', '77', '14', '7', '26', '8', '4', '13', '10', '17', '22', '20', '21', '9', '25', '99']
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '14', '3', '1', '27', '77', '7', '11', '26', '22', '25', '20', '13', '19', '21', '17', '10', '4', '9', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '3', '1', '77', '14', '7', '8', '11', '27', '22', '20', '19', '26', '13', '21', '99', '17', '4', '9', '10', '25']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['6', '44', '3', '14', '27', '22', '19', '8', '17', '20', '9', '7', '10', '4', '21', '77', '25', '99', '26', '1', '11', '13']
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['3', '6', '1', '22', '27', '14', '77', '25', '20', '7', '11', '19', '99', '21', '8', '26', '44', '10', '13', '9', '4', '17']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['6', '44', '77', '19', '14', '11', '20', '3', '27', '7', '22', '13', '99', '8', '17', '10', '4', '9', '21', '25', '1', '26']
# core           INFO 	Loading data for British Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '77', '3', '22', '1', '14', '20', '27', '26', '25', '11', '8', '99', '17', '10', '4', '13', '6', '9', '21', '19', '7']
# core           INFO 	Loading data for German Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['6', '77', '44', '1', '14', '3', '27', '22', '20', '11', '7', '13', '25', '21', '17', '10', '4', '9', '99', '26', '8', '19']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['3', '14', '44', '6', '19', '7', '1', '77', '25', '22', '99', '20', '13', '26', '17', '4', '21', '10', '11', '27', '8', '9']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['3', '6', '77', '7', '1', '22', '14', '11', '26', '27', '25', '20', '19', '99', '21', '4', '9', '17', '44', '8', '13', '45']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '19', '77', '3', '1', '11', '22', '7', '20', '26', '27', '25', '13', '99', '8', '10', '17', '21', '9', '14', '4']
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '1', '3', '14', '19', '25', '11', '7', '27', '20', '77', '13', '8', '26', '9', '17', '4', '22', '99', '21', '6', '10']
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 22 drivers: ['44', '6', '1', '3', '22', '77', '19', '27', '25', '11', '26', '7', '21', '20', '8', '13', '9', '4', '10', '17', '99', '14']
# core           INFO 	Loading data for Russian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 21 drivers: ['44', '6', '77', '22', '20', '14', '3', '1', '7', '11', '19', '27', '25', '26', '21', '99', '8', '13', '9', '10', '4']
# core           INFO 	Loading data for United States Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 18 drivers: ['44', '6', '3', '19', '77', '14', '1', '20', '13', '25', '8', '22', '7', '21', '26', '27', '11', '99']
# core           INFO 	Loading data for Brazilian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 18 drivers: ['6', '44', '19', '22', '1', '14', '7', '27', '20', '77', '26', '13', '25', '21', '11', '99', '8', '3']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '19', '77', '3', '22', '27', '11', '1', '14', '7', '20', '25', '8', '6', '21', '99', '46', '10', '13', '26']
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 18 drivers: ['44', '6', '5', '19', '12', '3', '27', '9', '55', '11', '22', '7', '33', '8', '13', '26', '20', '77']
# core           INFO 	Loading data for Malaysian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['5', '44', '6', '7', '77', '19', '33', '55', '26', '3', '8', '12', '11', '27', '98', '13', '22', '14', '9', '28']
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '6', '5', '7', '19', '77', '8', '12', '3', '9', '11', '14', '55', '22', '28', '98', '33', '13', '26', '27']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '7', '6', '77', '5', '3', '8', '11', '26', '19', '14', '12', '27', '9', '13', '28', '98', '33', '55', '22']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['6', '44', '5', '77', '7', '19', '3', '8', '55', '26', '33', '12', '11', '9', '27', '22', '28', '98', '13', '14']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['6', '5', '44', '26', '3', '7', '11', '22', '12', '55', '27', '8', '9', '77', '19', '98', '28', '33', '14', '13']
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '6', '77', '7', '5', '19', '13', '27', '26', '8', '11', '55', '3', '9', '33', '12', '28', '98', '22', '14']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['6', '44', '19', '5', '77', '27', '13', '33', '11', '3', '12', '26', '9', '98', '8', '55', '22', '28', '7', '14']
# core           INFO 	Loading data for British Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '6', '5', '19', '77', '26', '27', '7', '11', '14', '9', '98', '28', '55', '3', '33', '8', '13', '22', '12']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['5', '26', '3', '33', '14', '44', '8', '6', '22', '9', '12', '19', '77', '13', '98', '28', '55', '7', '11', '27']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '6', '8', '26', '11', '19', '7', '33', '77', '9', '12', '5', '14', '22', '98', '28', '55', '3', '13', '27']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '19', '77', '7', '11', '27', '3', '9', '26', '55', '33', '12', '22', '28', '98', '6', '14', '8', '13']
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['5', '3', '7', '6', '77', '26', '11', '33', '55', '12', '9', '13', '8', '53', '28', '22', '14', '44', '19', '27']
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1687, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['44', '6', '5', '7', '77', '27', '8', '13', '33', '55', '14', '11', '26', '9', '3', '22', '19', '53', '28', '12']
# core           INFO 	Loading data for Russian Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# _api          DEBUG 	Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
# ...
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# core        WARNING 	Failed to load extended driver information!
# core          DEBUG 	Exception while loading driver list
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 2291, in _drivers_from_f1_api
#     f1di = api.driver_info(self.api_path, livedata=livedata)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1533, in driver_info
#     response = fetch_page(path, 'driver_list')
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1725, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load result data from Ergast!
# logger        DEBUG 	Traceback for failure in ergast result data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 2348, in _get_data
#     return self._ergast.get_race_results(
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 1059, in get_race_results
#     return self._build_default_result(endpoint='results',
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 591, in _build_default_result
#     return self._build_result(
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 530, in _build_result
#     resp = cls._get(url, params)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 491, in _get
#     r = Cache.requests_get(url, headers=HEADERS, params=params,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# core        WARNING 	Failed to load driver list and session results!
# core           INFO 	Finished loading data for 0 drivers: []
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# logger      WARNING 	Failed to load session info data!
# logger        DEBUG 	Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 1470, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1685, in session_info
#     response = fetch_page(path, 'session_info')
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1725, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# core        WARNING 	Failed to load extended driver information!
# core          DEBUG 	Exception while loading driver list
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 2291, in _drivers_from_f1_api
#     f1di = api.driver_info(self.api_path, livedata=livedata)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1533, in driver_info
#     response = fetch_page(path, 'driver_list')
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/_api.py", line 1725, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load result data from Ergast!
# logger        DEBUG 	Traceback for failure in ergast result data
# Traceback (most recent call last):
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/core.py", line 2348, in _get_data
#     return self._ergast.get_race_results(
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 1059, in get_race_results
#     return self._build_default_result(endpoint='results',
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 591, in _build_default_result
#     return self._build_result(
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 530, in _build_result
#     resp = cls._get(url, params)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/ergast/interface.py", line 491, in _get
#     r = Cache.requests_get(url, headers=HEADERS, params=params,
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#   File "/Users/abhiattaluri/miniforge3/envs/f1env/lib/python3.10/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# core        WARNING 	Failed to load driver list and session results!
# core           INFO 	Finished loading data for 0 drivers: []

# %%
print(len(raceData.keys()))
raceData.keys()
# Out:
# 38
# dict_keys(['Australian Grand Prix', 'Malaysian Grand Prix', 'Bahrain Grand Prix', 'Chinese Grand Prix', 'Spanish Grand Prix', 'Monaco Grand Prix', 'Canadian Grand Prix', 'Austrian Grand Prix', 'British Grand Prix', 'German Grand Prix', 'Hungarian Grand Prix', 'Belgian Grand Prix', 'Italian Grand Prix', 'Singapore Grand Prix', 'Japanese Grand Prix', 'Russian Grand Prix', 'United States Grand Prix', 'Brazilian Grand Prix', 'Abu Dhabi Grand Prix', 'Mexican Grand Prix', 'European Grand Prix', 'Azerbaijan Grand Prix', 'French Grand Prix', 'Styrian Grand Prix', '70th Anniversary Grand Prix', 'Tuscan Grand Prix', 'Eifel Grand Prix', 'Portuguese Grand Prix', 'Emilia Romagna Grand Prix', 'Turkish Grand Prix', 'Sakhir Grand Prix', 'Dutch Grand Prix', 'Mexico City Grand Prix', 'São Paulo Grand Prix', 'Qatar Grand Prix', 'Saudi Arabian Grand Prix', 'Miami Grand Prix', 'Las Vegas Grand Prix'])

# %%
for key in raceData:
    print(len(raceData[key]))
# Out:
# 9
# 4
# 11
# 7
# 11
# 10
# 9
# 11
# 11
# 4
# 11
# 11
# 11
# 9
# 9
# 8
# 10
# 6
# 11
# 5
# 1
# 7
# 4
# 2
# 1
# 1
# 1
# 2
# 4
# 2
# 1
# 4
# 4
# 4
# 3
# 4
# 3
# 2

# %%
raceData['Abu Dhabi Grand Prix'][4]
# Out:
#    DriverNumber Abbreviation         DriverId         TeamName       TeamId  \
# 44           44          HAM         hamilton         Mercedes     mercedes
# 5             5          VET           vettel          Ferrari      ferrari
# 33           33          VER   max_verstappen  Red Bull Racing     red_bull
# 3             3          RIC        ricciardo  Red Bull Racing     red_bull
# 77           77          BOT           bottas         Mercedes     mercedes
# 55           55          SAI            sainz          Renault      renault
# 16           16          LEC          leclerc           Sauber       sauber
# 11           11          PER            perez     Racing Point  force_india
# 8             8          GRO         grosjean     Haas F1 Team         haas
# 20           20          MAG  kevin_magnussen     Haas F1 Team         haas
# 14           14          ALO           alonso          McLaren      mclaren
# 28           28          HAR  brendon_hartley       Toro Rosso   toro_rosso
# 18           18          STR           stroll         Williams     williams
# 2             2          VAN        vandoorne          McLaren      mclaren
# 35           35          SIR         sirotkin         Williams     williams
# 10           10          GAS            gasly       Toro Rosso   toro_rosso
# 31           31          OCO             ocon     Racing Point  force_india
# 9             9          ERI         ericsson           Sauber       sauber
# 7             7          RAI        raikkonen          Ferrari      ferrari
# 27           27          HUL       hulkenberg          Renault      renault
#
#     FirstName    LastName           FullName  Position ClassifiedPosition  \
# 44      Lewis    Hamilton     Lewis Hamilton       1.0                  1
# 5   Sebastian      Vettel   Sebastian Vettel       2.0                  2
# 33        Max  Verstappen     Max Verstappen       3.0                  3
# 3      Daniel   Ricciardo   Daniel Ricciardo       4.0                  4
# 77   Valtteri      Bottas    Valtteri Bottas       5.0                  5
# 55     Carlos       Sainz       Carlos Sainz       6.0                  6
# 16    Charles     Leclerc    Charles Leclerc       7.0                  7
# 11     Sergio       Perez       Sergio Perez       8.0                  8
# 8      Romain    Grosjean    Romain Grosjean       9.0                  9
# 20      Kevin   Magnussen    Kevin Magnussen      10.0                 10
# 14   Fernando      Alonso    Fernando Alonso      11.0                 11
# 28    Brendon     Hartley    Brendon Hartley      12.0                 12
# 18      Lance      Stroll       Lance Stroll      13.0                 13
# 2     Stoffel   Vandoorne  Stoffel Vandoorne      14.0                 14
# 35     Sergey    Sirotkin    Sergey Sirotkin      15.0                 15
# 10     Pierre       Gasly       Pierre Gasly      16.0                  R
# 31    Esteban        Ocon       Esteban Ocon      17.0                  R
# 9      Marcus    Ericsson    Marcus Ericsson      18.0                  R
# 7        Kimi   Räikkönen     Kimi Räikkönen      19.0                  R
# 27       Nico  Hulkenberg    Nico Hulkenberg      20.0                  R
#
#     GridPosition  Q1  Q2  Q3                   Time      Status  Points  \
# 44           1.0 NaT NaT NaT 0 days 01:39:40.382000    Finished    25.0
# 5            3.0 NaT NaT NaT 0 days 00:00:02.581000    Finished    18.0
# 33           6.0 NaT NaT NaT 0 days 00:00:12.706000    Finished    15.0
# 3            5.0 NaT NaT NaT 0 days 00:00:15.379000    Finished    12.0
# 77           2.0 NaT NaT NaT 0 days 00:00:47.957000    Finished    10.0
# 55          11.0 NaT NaT NaT 0 days 00:01:12.548000    Finished     8.0
# 16           8.0 NaT NaT NaT 0 days 00:01:30.789000    Finished     6.0
# 11          14.0 NaT NaT NaT 0 days 00:01:31.275000    Finished     4.0
# 8            7.0 NaT NaT NaT                    NaT      +1 Lap     2.0
# 20          13.0 NaT NaT NaT                    NaT      +1 Lap     1.0
# 14          15.0 NaT NaT NaT                    NaT      +1 Lap     0.0
# 28          16.0 NaT NaT NaT                    NaT      +1 Lap     0.0
# 18          20.0 NaT NaT NaT                    NaT      +1 Lap     0.0
# 2           18.0 NaT NaT NaT                    NaT      +1 Lap     0.0
# 35          19.0 NaT NaT NaT                    NaT      +1 Lap     0.0
# 10          17.0 NaT NaT NaT                    NaT      Engine     0.0
# 31           9.0 NaT NaT NaT                    NaT      Engine     0.0
# 9           12.0 NaT NaT NaT                    NaT  Power loss     0.0
# 7            4.0 NaT NaT NaT                    NaT  Power loss     0.0
# 27          10.0 NaT NaT NaT                    NaT   Collision     0.0
#
#     PositionChange  Year                 Event
# 44             0.0  2018  Abu Dhabi Grand Prix
# 5              1.0  2018  Abu Dhabi Grand Prix
# 33             3.0  2018  Abu Dhabi Grand Prix
# 3              1.0  2018  Abu Dhabi Grand Prix
# 77            -3.0  2018  Abu Dhabi Grand Prix
# 55             5.0  2018  Abu Dhabi Grand Prix
# 16             1.0  2018  Abu Dhabi Grand Prix
# 11             6.0  2018  Abu Dhabi Grand Prix
# 8             -2.0  2018  Abu Dhabi Grand Prix
# 20             3.0  2018  Abu Dhabi Grand Prix
# 14             4.0  2018  Abu Dhabi Grand Prix
# 28             4.0  2018  Abu Dhabi Grand Prix
# 18             7.0  2018  Abu Dhabi Grand Prix
# 2              4.0  2018  Abu Dhabi Grand Prix
# 35             4.0  2018  Abu Dhabi Grand Prix
# 10             1.0  2018  Abu Dhabi Grand Prix
# 31            -8.0  2018  Abu Dhabi Grand Prix
# 9             -6.0  2018  Abu Dhabi Grand Prix
# 7            -15.0  2018  Abu Dhabi Grand Prix
# 27           -10.0  2018  Abu Dhabi Grand Prix

# %%
genCount = 0
fullCount = 0
emptyCount = 0
for key in raceData:
    if len(raceData[key]) == 11:
        genCount += 1
        if raceData[key][10].shape[0] > 0:
            fullCount += 1
            print('full', key)
        else:
            emptyCount += 1
            print('empty', key)

print(genCount)
print(fullCount)
print(emptyCount)
# Out:
# full Bahrain Grand Prix
# empty Spanish Grand Prix
# empty Austrian Grand Prix
# empty British Grand Prix
# empty Hungarian Grand Prix
# empty Belgian Grand Prix
# empty Italian Grand Prix
# empty Abu Dhabi Grand Prix
# 8
# 1
# 7

# %%
raceData['Miami Grand Prix'][0]
# Out:
#    DriverNumber Abbreviation DriverId         TeamName TeamId  FirstName  \
# 16           16          LEC                   Ferrari           Charles
# 55           55          SAI                   Ferrari            Carlos
# 1             1          VER           Red Bull Racing               Max
# 11           11          PER           Red Bull Racing            Sergio
# 77           77          BOT                Alfa Romeo          Valtteri
# 44           44          HAM                  Mercedes             Lewis
# 10           10          GAS                AlphaTauri            Pierre
# 4             4          NOR                   McLaren             Lando
# 22           22          TSU                AlphaTauri              Yuki
# 18           18          STR              Aston Martin             Lance
# 14           14          ALO                    Alpine          Fernando
# 63           63          RUS                  Mercedes            George
# 5             5          VET              Aston Martin         Sebastian
# 3             3          RIC                   McLaren            Daniel
# 47           47          MSC              Haas F1 Team              Mick
# 20           20          MAG              Haas F1 Team             Kevin
# 24           24          ZHO                Alfa Romeo            Guanyu
# 23           23          ALB                  Williams         Alexander
# 6             6          LAT                  Williams          Nicholas
# 31           31          OCO                    Alpine           Esteban
#
#       LastName          FullName  Position ClassifiedPosition  GridPosition  \
# 16     Leclerc   Charles Leclerc       NaN                              NaN
# 55       Sainz      Carlos Sainz       NaN                              NaN
# 1   Verstappen    Max Verstappen       NaN                              NaN
# 11       Perez      Sergio Perez       NaN                              NaN
# 77      Bottas   Valtteri Bottas       NaN                              NaN
# 44    Hamilton    Lewis Hamilton       NaN                              NaN
# 10       Gasly      Pierre Gasly       NaN                              NaN
# 4       Norris      Lando Norris       NaN                              NaN
# 22     Tsunoda      Yuki Tsunoda       NaN                              NaN
# 18      Stroll      Lance Stroll       NaN                              NaN
# 14      Alonso   Fernando Alonso       NaN                              NaN
# 63     Russell    George Russell       NaN                              NaN
# 5       Vettel  Sebastian Vettel       NaN                              NaN
# 3    Ricciardo  Daniel Ricciardo       NaN                              NaN
# 47  Schumacher   Mick Schumacher       NaN                              NaN
# 20   Magnussen   Kevin Magnussen       NaN                              NaN
# 24        Zhou       Guanyu Zhou       NaN                              NaN
# 23       Albon   Alexander Albon       NaN                              NaN
# 6       Latifi   Nicholas Latifi       NaN                              NaN
# 31        Ocon      Esteban Ocon       NaN                              NaN
#
#     Q1  Q2  Q3 Time Status  Points  PositionChange  Year             Event
# 16 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 55 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 1  NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 11 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 77 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 44 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 10 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 4  NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 22 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 18 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 14 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 63 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 5  NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 3  NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 47 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 20 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 24 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 23 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 6  NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix
# 31 NaT NaT NaT  NaT            NaN             NaN  2022  Miami Grand Prix

# %%
raceData['Spanish Grand Prix'][10]
# Out:
# Empty DataFrame
# Columns: [DriverNumber, Abbreviation, DriverId, TeamName, TeamId, FirstName, LastName, FullName, Position, ClassifiedPosition, GridPosition, Q1, Q2, Q3, Time, Status, Points, PositionChange, Year, Event]
# Index: []

# %%
empty = []
for key in raceData:
    for idx in range(len(raceData[key])):
        df = raceData[key][idx]
        if df.shape[0] > 0:
            year = df['Year'].iloc[0]
            df.to_csv(f'data/{key}-{year}.csv', index=False)
        else:
            year = 2014 + idx
            race = f'{key}-{year}'
            empty.append(race)
